# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pathlib
import numpy as np
import random
import matplotlib.pyplot as plt
import os
import pandas as pd
import tensorflow as tf
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation, Rescaling, RandomZoom
from sklearn.utils.class_weight import compute_class_weight

# %%
# Set the path to the split dataset directory
split_dataset_dir = '/content/drive/MyDrive/Dataset_divided'

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
    tf.keras.layers.experimental.preprocessing.RandomZoom(0.2),
])

# %%
# Load data with consistent normalization and get labels for training
X_train = tf.keras.preprocessing.image_dataset_from_directory(
    os.path.join(split_dataset_dir, 'train'),
    seed=1,
    image_size=(128, 128),
    batch_size=32,
).map(lambda x, y: (data_augmentation(x, training=True), y))
import numpy as np


# Load data with consistent normalization for validation
X_validation = tf.keras.preprocessing.image_dataset_from_directory(
    os.path.join(split_dataset_dir, 'valid'),
    seed=1,
    image_size=(128, 128),
    batch_size=32,
).map(lambda x, y: (data_augmentation(x, training=False), y))
# Out:
# Found 7350 files belonging to 4 classes.
# Found 1578 files belonging to 4 classes.

# %%
# Preprocess the data
AUTOTUNE = tf.data.AUTOTUNE
X_train = X_train.prefetch(buffer_size=AUTOTUNE)
X_validation = X_validation.prefetch(buffer_size=AUTOTUNE)

# %%
# Early Stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=20,  # Increase patience
    restore_best_weights=True
)

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard

# DenseNet121 model with Batch Normalization and Dropout
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(128, 128, 3))


model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    BatchNormalization(),
    Dropout(0.6),
    Dense(128, activation='relu', kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    Dropout(0.6),
    Dense(128, activation='relu', kernel_regularizer=l2(0.01)),  # Additional Dense layer with regularization
    BatchNormalization(),
    Dropout(0.6),  # Increase dropout rate
    Dense(4, activation='softmax')
])


# Learning Rate Scheduler Adjustment
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=5e-4,  # Reduced initial learning rate
    decay_steps=1000,
    decay_rate=0.8
)

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=['accuracy']
)

# Specify the path and filename for saving the model
model_save_path = '/content/drive/MyDrive/saved_model/Dense_Net_121_Model.h5'

# Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=20, verbose=1, mode='min', restore_best_weights=True),
    ModelCheckpoint(model_save_path, monitor='val_loss', save_best_only=True, verbose=1),
    TensorBoard(log_dir='./logs', histogram_freq=1)
]

# Data Augmentation Configuration
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 4, 4, 1024)        7037504
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  batch_normalization (Batch  (None, 1024)              4096
#  Normalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  batch_normalization_1 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  batch_normalization_2 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 7190852 (27.43 MB)
# Trainable params: 7104644 (27.10 MB)
# Non-trainable params: 86208 (336.75 KB)
# _________________________________________________________________

# %%
# Model Training
history = model.fit(
    X_train,
    epochs=100,
    validation_data=X_validation,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 230/230 [==============================] - 1068s 4s/step - loss: 4.5077 - accuracy: 0.4136 - val_loss: 4.6481 - val_accuracy: 0.3834
# Epoch 2/100
# 230/230 [==============================] - 59s 253ms/step - loss: 3.4179 - accuracy: 0.4816 - val_loss: 3.7185 - val_accuracy: 0.5431
# Epoch 3/100
# 230/230 [==============================] - 58s 249ms/step - loss: 2.8698 - accuracy: 0.5210 - val_loss: 3.0393 - val_accuracy: 0.4303
# Epoch 4/100
# 230/230 [==============================] - 58s 250ms/step - loss: 2.4245 - accuracy: 0.5906 - val_loss: 2.5640 - val_accuracy: 0.5906
# Epoch 5/100
# 230/230 [==============================] - 60s 257ms/step - loss: 2.0306 - accuracy: 0.6378 - val_loss: 1.8053 - val_accuracy: 0.6787
# Epoch 6/100
# 230/230 [==============================] - 59s 252ms/step - loss: 1.7196 - accuracy: 0.6693 - val_loss: 1.5036 - val_accuracy: 0.7053
# Epoch 7/100
# 230/230 [==============================] - 59s 252ms/step - loss: 1.4612 - accuracy: 0.6903 - val_loss: 1.5845 - val_accuracy: 0.6166
# Epoch 8/100
# 230/230 [==============================] - 61s 260ms/step - loss: 1.2807 - accuracy: 0.6963 - val_loss: 1.4235 - val_accuracy: 0.5989
# Epoch 9/100
# 230/230 [==============================] - 59s 249ms/step - loss: 1.1115 - accuracy: 0.7118 - val_loss: 2.0120 - val_accuracy: 0.4030
# Epoch 10/100
# 230/230 [==============================] - 60s 255ms/step - loss: 0.9771 - accuracy: 0.7261 - val_loss: 0.9191 - val_accuracy: 0.7351
# Epoch 11/100
# 230/230 [==============================] - 59s 255ms/step - loss: 0.8921 - accuracy: 0.7316 - val_loss: 0.8338 - val_accuracy: 0.7338
# Epoch 12/100
# 230/230 [==============================] - 63s 269ms/step - loss: 0.8144 - accuracy: 0.7378 - val_loss: 0.7835 - val_accuracy: 0.7212
# Epoch 13/100
# 230/230 [==============================] - 64s 276ms/step - loss: 0.7434 - accuracy: 0.7465 - val_loss: 0.8126 - val_accuracy: 0.7117
# Epoch 14/100
# 230/230 [==============================] - 59s 255ms/step - loss: 0.7125 - accuracy: 0.7419 - val_loss: 0.6658 - val_accuracy: 0.7357
# Epoch 15/100
# 230/230 [==============================] - 59s 253ms/step - loss: 0.6639 - accuracy: 0.7430 - val_loss: 1.1715 - val_accuracy: 0.5691
# Epoch 16/100
# 230/230 [==============================] - 59s 254ms/step - loss: 0.6332 - accuracy: 0.7551 - val_loss: 0.6446 - val_accuracy: 0.7529
# Epoch 17/100
# 230/230 [==============================] - 59s 254ms/step - loss: 0.6212 - accuracy: 0.7554 - val_loss: 0.6201 - val_accuracy: 0.7440
# Epoch 18/100
# 230/230 [==============================] - 60s 256ms/step - loss: 0.5888 - accuracy: 0.7710 - val_loss: 0.5842 - val_accuracy: 0.7750
# Epoch 19/100
# 230/230 [==============================] - 59s 253ms/step - loss: 0.5687 - accuracy: 0.7735 - val_loss: 0.5586 - val_accuracy: 0.7852
# Epoch 20/100
# 230/230 [==============================] - 59s 254ms/step - loss: 0.5582 - accuracy: 0.7776 - val_loss: 0.5200 - val_accuracy: 0.7997
# Epoch 21/100
# 230/230 [==============================] - 60s 254ms/step - loss: 0.5310 - accuracy: 0.7849 - val_loss: 0.8103 - val_accuracy: 0.6394
# Epoch 22/100
# 230/230 [==============================] - 59s 253ms/step - loss: 0.5154 - accuracy: 0.7899 - val_loss: 0.6012 - val_accuracy: 0.7782
# Epoch 23/100
# 230/230 [==============================] - 58s 251ms/step - loss: 0.4982 - accuracy: 0.8011 - val_loss: 0.6530 - val_accuracy: 0.7484
# Epoch 24/100
# 230/230 [==============================] - 59s 250ms/step - loss: 0.4998 - accuracy: 0.8071 - val_loss: 0.5802 - val_accuracy: 0.7541
# Epoch 25/100
# 230/230 [==============================] - 58s 246ms/step - loss: 0.4767 - accuracy: 0.8117 - val_loss: 0.6515 - val_accuracy: 0.7611
# Epoch 26/100
# 230/230 [==============================] - 58s 248ms/step - loss: 0.4694 - accuracy: 0.8182 - val_loss: 0.6601 - val_accuracy: 0.7402
# Epoch 27/100
# 230/230 [==============================] - 59s 254ms/step - loss: 0.4406 - accuracy: 0.8309 - val_loss: 0.5782 - val_accuracy: 0.7630
# Epoch 28/100
# 230/230 [==============================] - 59s 251ms/step - loss: 0.4263 - accuracy: 0.8346 - val_loss: 0.4488 - val_accuracy: 0.8302
# Epoch 29/100
# 230/230 [==============================] - 58s 248ms/step - loss: 0.4226 - accuracy: 0.8422 - val_loss: 0.5338 - val_accuracy: 0.8010
# Epoch 30/100
# 230/230 [==============================] - 60s 255ms/step - loss: 0.3924 - accuracy: 0.8483 - val_loss: 0.5403 - val_accuracy: 0.7643
# Epoch 31/100
# 230/230 [==============================] - 59s 251ms/step - loss: 0.3643 - accuracy: 0.8646 - val_loss: 1.1388 - val_accuracy: 0.6286
# Epoch 32/100
# 230/230 [==============================] - 58s 249ms/step - loss: 0.3627 - accuracy: 0.8624 - val_loss: 0.4554 - val_accuracy: 0.8384
# Epoch 33/100
# 230/230 [==============================] - 64s 274ms/step - loss: 0.3378 - accuracy: 0.8788 - val_loss: 0.5463 - val_accuracy: 0.7985
# Epoch 34/100
# 230/230 [==============================] - 57s 245ms/step - loss: 0.3139 - accuracy: 0.8845 - val_loss: 0.7482 - val_accuracy: 0.7833
# Epoch 35/100
# 230/230 [==============================] - 59s 251ms/step - loss: 0.2991 - accuracy: 0.8961 - val_loss: 0.3479 - val_accuracy: 0.8777
# Epoch 36/100
# 230/230 [==============================] - 59s 253ms/step - loss: 0.2935 - accuracy: 0.8958 - val_loss: 0.4725 - val_accuracy: 0.8428
# Epoch 37/100
# 230/230 [==============================] - 59s 251ms/step - loss: 0.2742 - accuracy: 0.9060 - val_loss: 0.4134 - val_accuracy: 0.8447
# Epoch 38/100
# 230/230 [==============================] - 65s 278ms/step - loss: 0.2715 - accuracy: 0.9072 - val_loss: 0.7357 - val_accuracy: 0.7864
# Epoch 39/100
# 230/230 [==============================] - 59s 254ms/step - loss: 0.2356 - accuracy: 0.9276 - val_loss: 0.3999 - val_accuracy: 0.8663
# Epoch 40/100
# 230/230 [==============================] - 59s 253ms/step - loss: 0.2280 - accuracy: 0.9267 - val_loss: 0.4833 - val_accuracy: 0.8340
# Epoch 41/100
# 230/230 [==============================] - 60s 256ms/step - loss: 0.2159 - accuracy: 0.9305 - val_loss: 0.6724 - val_accuracy: 0.7890
# Epoch 42/100
# 230/230 [==============================] - 59s 253ms/step - loss: 0.2194 - accuracy: 0.9291 - val_loss: 0.5672 - val_accuracy: 0.8023
# Epoch 43/100
# 230/230 [==============================] - 58s 249ms/step - loss: 0.1872 - accuracy: 0.9412 - val_loss: 0.3542 - val_accuracy: 0.8657
# Epoch 44/100
# 230/230 [==============================] - 60s 257ms/step - loss: 0.1879 - accuracy: 0.9415 - val_loss: 0.3566 - val_accuracy: 0.8872
# Epoch 45/100
# 230/230 [==============================] - 58s 247ms/step - loss: 0.1758 - accuracy: 0.9452 - val_loss: 0.5076 - val_accuracy: 0.8378
# Epoch 46/100
# 230/230 [==============================] - 57s 243ms/step - loss: 0.1586 - accuracy: 0.9517 - val_loss: 0.3598 - val_accuracy: 0.8777
# Epoch 47/100
# 230/230 [==============================] - 58s 246ms/step - loss: 0.1640 - accuracy: 0.9541 - val_loss: 0.5225 - val_accuracy: 0.8447
# Epoch 48/100
# 230/230 [==============================] - 58s 248ms/step - loss: 0.1532 - accuracy: 0.9540 - val_loss: 0.3430 - val_accuracy: 0.8923
# Epoch 49/100
# 230/230 [==============================] - 59s 253ms/step - loss: 0.1245 - accuracy: 0.9659 - val_loss: 0.3429 - val_accuracy: 0.8980
# Epoch 50/100
# 230/230 [==============================] - 58s 248ms/step - loss: 0.1384 - accuracy: 0.9622 - val_loss: 0.2918 - val_accuracy: 0.9132
# Epoch 51/100
# 230/230 [==============================] - 59s 252ms/step - loss: 0.1231 - accuracy: 0.9657 - val_loss: 0.2928 - val_accuracy: 0.9125
# Epoch 52/100
# 230/230 [==============================] - 59s 252ms/step - loss: 0.1093 - accuracy: 0.9671 - val_loss: 0.3238 - val_accuracy: 0.9024
# Epoch 53/100
# 230/230 [==============================] - 58s 250ms/step - loss: 0.1109 - accuracy: 0.9694 - val_loss: 0.2914 - val_accuracy: 0.9100
# Epoch 54/100
# 230/230 [==============================] - 59s 251ms/step - loss: 0.1057 - accuracy: 0.9706 - val_loss: 0.2950 - val_accuracy: 0.9189
# Epoch 55/100
# 230/230 [==============================] - 58s 250ms/step - loss: 0.1057 - accuracy: 0.9695 - val_loss: 0.3657 - val_accuracy: 0.8942
# Epoch 56/100
# 230/230 [==============================] - 58s 249ms/step - loss: 0.0977 - accuracy: 0.9746 - val_loss: 0.2754 - val_accuracy: 0.9157
# Epoch 57/100
# 230/230 [==============================] - 63s 270ms/step - loss: 0.0908 - accuracy: 0.9765 - val_loss: 0.3046 - val_accuracy: 0.9119
# Epoch 58/100
# 230/230 [==============================] - 58s 247ms/step - loss: 0.0847 - accuracy: 0.9784 - val_loss: 0.3367 - val_accuracy: 0.9005
# Epoch 59/100
# 230/230 [==============================] - 60s 257ms/step - loss: 0.0909 - accuracy: 0.9754 - val_loss: 0.2479 - val_accuracy: 0.9328
# Epoch 60/100
# 230/230 [==============================] - 59s 252ms/step - loss: 0.0822 - accuracy: 0.9780 - val_loss: 0.2983 - val_accuracy: 0.9151
# Epoch 61/100
# 230/230 [==============================] - 59s 251ms/step - loss: 0.0803 - accuracy: 0.9796 - val_loss: 0.2931 - val_accuracy: 0.9138
# Epoch 62/100
# 230/230 [==============================] - 59s 252ms/step - loss: 0.0771 - accuracy: 0.9819 - val_loss: 0.3523 - val_accuracy: 0.9011
# Epoch 63/100
# 230/230 [==============================] - 58s 248ms/step - loss: 0.0710 - accuracy: 0.9823 - val_loss: 0.2486 - val_accuracy: 0.9316
# Epoch 64/100
# 230/230 [==============================] - 65s 278ms/step - loss: 0.0766 - accuracy: 0.9804 - val_loss: 0.2426 - val_accuracy: 0.9309
# Epoch 65/100
# 230/230 [==============================] - 59s 254ms/step - loss: 0.0782 - accuracy: 0.9822 - val_loss: 0.2995 - val_accuracy: 0.9138
# Epoch 66/100
# 230/230 [==============================] - 59s 252ms/step - loss: 0.0568 - accuracy: 0.9883 - val_loss: 0.2740 - val_accuracy: 0.9202
# Epoch 67/100
# 230/230 [==============================] - 58s 249ms/step - loss: 0.0716 - accuracy: 0.9842 - val_loss: 0.2677 - val_accuracy: 0.9240
# Epoch 68/100
# 230/230 [==============================] - 59s 251ms/step - loss: 0.0623 - accuracy: 0.9849 - val_loss: 0.2234 - val_accuracy: 0.9385
# Epoch 69/100
# 230/230 [==============================] - 58s 250ms/step - loss: 0.0645 - accuracy: 0.9842 - val_loss: 0.3111 - val_accuracy: 0.9170
# Epoch 70/100
# 230/230 [==============================] - 59s 253ms/step - loss: 0.0524 - accuracy: 0.9884 - val_loss: 0.2895 - val_accuracy: 0.9202
# Epoch 71/100
# 230/230 [==============================] - 58s 248ms/step - loss: 0.0505 - accuracy: 0.9897 - val_loss: 0.2945 - val_accuracy: 0.9240
# Epoch 72/100
# 230/230 [==============================] - 58s 250ms/step - loss: 0.0608 - accuracy: 0.9854 - val_loss: 0.2563 - val_accuracy: 0.9347
# Epoch 73/100
# 230/230 [==============================] - 59s 249ms/step - loss: 0.0517 - accuracy: 0.9895 - val_loss: 0.2683 - val_accuracy: 0.9284
# Epoch 74/100
# 230/230 [==============================] - 58s 247ms/step - loss: 0.0550 - accuracy: 0.9875 - val_loss: 0.2363 - val_accuracy: 0.9322
# Epoch 75/100
# 230/230 [==============================] - 60s 256ms/step - loss: 0.0519 - accuracy: 0.9883 - val_loss: 0.2179 - val_accuracy: 0.9360
# Epoch 76/100
# 230/230 [==============================] - 59s 252ms/step - loss: 0.0474 - accuracy: 0.9891 - val_loss: 0.2575 - val_accuracy: 0.9265
# Epoch 77/100
# 230/230 [==============================] - 59s 254ms/step - loss: 0.0479 - accuracy: 0.9899 - val_loss: 0.2129 - val_accuracy: 0.9430
# Epoch 78/100
# 230/230 [==============================] - 58s 248ms/step - loss: 0.0480 - accuracy: 0.9894 - val_loss: 0.2385 - val_accuracy: 0.9271
# Epoch 79/100
# 230/230 [==============================] - 59s 251ms/step - loss: 0.0489 - accuracy: 0.9879 - val_loss: 0.2362 - val_accuracy: 0.9309
# Epoch 80/100
# 230/230 [==============================] - 59s 252ms/step - loss: 0.0512 - accuracy: 0.9879 - val_loss: 0.2190 - val_accuracy: 0.9411
# Epoch 81/100
# 230/230 [==============================] - 58s 250ms/step - loss: 0.0420 - accuracy: 0.9916 - val_loss: 0.2283 - val_accuracy: 0.9341
# Epoch 82/100
# 230/230 [==============================] - 59s 253ms/step - loss: 0.0429 - accuracy: 0.9910 - val_loss: 0.2495 - val_accuracy: 0.9341
# Epoch 83/100
# 230/230 [==============================] - 60s 256ms/step - loss: 0.0412 - accuracy: 0.9925 - val_loss: 0.2477 - val_accuracy: 0.9354
# Epoch 84/100
# 230/230 [==============================] - 60s 256ms/step - loss: 0.0369 - accuracy: 0.9929 - val_loss: 0.2459 - val_accuracy: 0.9316
# Epoch 85/100
# 230/230 [==============================] - 59s 251ms/step - loss: 0.0415 - accuracy: 0.9913 - val_loss: 0.2518 - val_accuracy: 0.9379
# Epoch 86/100
# 230/230 [==============================] - 59s 255ms/step - loss: 0.0413 - accuracy: 0.9921 - val_loss: 0.2535 - val_accuracy: 0.9303
# Epoch 87/100
# 230/230 [==============================] - 59s 250ms/step - loss: 0.0417 - accuracy: 0.9907 - val_loss: 0.2354 - val_accuracy: 0.9404
# Epoch 88/100
# 230/230 [==============================] - 58s 250ms/step - loss: 0.0398 - accuracy: 0.9920 - val_loss: 0.2414 - val_accuracy: 0.9379
# Epoch 89/100
# 230/230 [==============================] - 59s 251ms/step - loss: 0.0380 - accuracy: 0.9928 - val_loss: 0.2389 - val_accuracy: 0.9341
# Epoch 90/100
# 230/230 [==============================] - 58s 250ms/step - loss: 0.0412 - accuracy: 0.9914 - val_loss: 0.2603 - val_accuracy: 0.9284
# Epoch 91/100
# 230/230 [==============================] - 59s 252ms/step - loss: 0.0447 - accuracy: 0.9909 - val_loss: 0.2309 - val_accuracy: 0.9347
# Epoch 92/100
# 230/230 [==============================] - 58s 247ms/step - loss: 0.0378 - accuracy: 0.9929 - val_loss: 0.2425 - val_accuracy: 0.9322
# Epoch 93/100
# 230/230 [==============================] - 58s 250ms/step - loss: 0.0338 - accuracy: 0.9948 - val_loss: 0.2513 - val_accuracy: 0.9290
# Epoch 94/100
# 230/230 [==============================] - 59s 251ms/step - loss: 0.0340 - accuracy: 0.9944 - val_loss: 0.2346 - val_accuracy: 0.9335
# Epoch 95/100
# 230/230 [==============================] - 58s 251ms/step - loss: 0.0337 - accuracy: 0.9935 - val_loss: 0.2364 - val_accuracy: 0.9347
# Epoch 96/100
# 230/230 [==============================] - 59s 254ms/step - loss: 0.0364 - accuracy: 0.9935 - val_loss: 0.2342 - val_accuracy: 0.9347
# Epoch 97/100
# 230/230 [==============================] - 59s 250ms/step - loss: 0.0349 - accuracy: 0.9937 - val_loss: 0.2180 - val_accuracy: 0.9385

# %%
# Save the entire model to a HDF5 file
model.save('/content/drive/MyDrive/saved_model/Dense_Net_121_Model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model from the HDF5 file
loaded_model = tf.keras.models.load_model('/content/drive/MyDrive/saved_model/Dense_Net_121_Model.h5')

# %%
# Save the entire model to Google Drive
loaded_model.save('/content/drive/MyDrive/saved_model/Dense_Net_121_Model.h5')

# %%
model_evaluate = model.evaluate(X_validation)
print("Accuracy: %", "{:.2f}".format(model_evaluate[1]*100))
print("Loss: %", "{:.2f}".format(model_evaluate[0]*100))
# Out:
# 50/50 [==============================] - 6s 90ms/step - loss: 0.2129 - accuracy: 0.9430
# Accuracy: % 94.30
# Loss: % 21.29

# %%
# Save the updated model with the same name
loaded_model.save('/content/drive/MyDrive/saved_model/Dense_Net_121_Model.h5')

# %%
df = pd.DataFrame(history.history)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Plot accuracy
ax1.plot(df['accuracy'], label='Training Accuracy', lw=3)
ax1.plot(df['val_accuracy'], label='Validation Accuracy', lw=3)
ax1.set_title('Accuracy per Epoch', fontsize=18, fontweight='bold')
ax1.set_xlabel('Epochs', fontsize=15, fontweight='bold')
ax1.legend()

# Plot loss
ax2.plot(df['loss'], label='Training Loss', lw=3)
ax2.plot(df['val_loss'], label='Validation Loss', lw=3)
ax2.set_title('Loss per Epoch', fontsize=18, fontweight='bold')
ax2.set_xlabel('Epochs', fontsize=15, fontweight='bold')
ax2.legend()

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pathlib
import numpy as np
import matplotlib.pyplot as plt
import random
import os
import tensorflow as tf
import pandas as pd
df = pd.DataFrame(history.history)
ax = df.plot(figsize=(10,5), lw=3, grid='on')
ax.set_title('History per Epoch', fontsize=18, fontweight='bold')
ax.set_xlabel('Epochs', fontsize=15, fontweight='bold')
ax.plot()
# Out:
# []

# %%
# Save the entire model to Google Drive
loaded_model.save('/content/drive/MyDrive/saved_model/Dense_Net_121_Model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#model = tf.keras.models.load_model('/content/drive/MyDrive/saved_model/Xception_Model.h5')

# Visualize Training History
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Save the entire model to a HDF5 file
loaded_model.save('/content/drive/MyDrive/saved_model/Dense_Net_121_Model.h5')

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import os
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt


# Load the trained model
loaded_model = tf.keras.models.load_model('/content/drive/MyDrive/saved_model/Dense_Net_121_Model.h5')

# Set the path to the split dataset directory
split_dataset_dir = '/content/drive/MyDrive/Dataset_divided'

# Load the test dataset
test_data_dir = os.path.join(split_dataset_dir, 'test')
X_test = tf.keras.preprocessing.image_dataset_from_directory(
    test_data_dir,
    seed=1,
    image_size=(128, 128),
    batch_size=32
)

total_samples = 0
for images, labels in X_test:
    total_samples += len(labels)
print("Total samples in the test dataset:", total_samples)

# Make predictions on the test dataset
y_true = []
y_pred = []
for images, labels in X_test:
    predictions = loaded_model.predict(images)
    predicted_labels = np.argmax(predictions, axis=1)
    y_true.extend(labels.numpy())
    y_pred.extend(predicted_labels)

# Convert true and predicted labels to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))

# Calculate precision, recall, F1-score
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

print("Precision: {:.2f}".format(precision))
print("Recall: {:.2f}".format(recall))
print("F1 Score: {:.2f}".format(f1))

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Found 1574 files belonging to 4 classes.
# Total samples in the test dataset: 1574
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 4s 4s/step
# Accuracy: 93.52%
# Precision: 0.94
# Recall: 0.93
# F1 Score: 0.94

# %%
# Save the updated model with the same name
loaded_model.save('/content/drive/MyDrive/saved_model/Dense_Net_121_Model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
